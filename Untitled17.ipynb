# %%
import pandas as pd
df=pd.read_csv('D:\\AI ML B2\\CreditCard9.csv')
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer            45      M              3.0
# 1   818770008  Existing Customer            49      F              5.0
# 2   713982108  Existing Customer            51      M              3.0
# 3   769911858  Existing Customer            40      F              NaN
# 4   709106358  Existing Customer            40      M              3.0
# 5   713061558  Existing Customer            44      M              2.0
# 6   810347208  Existing Customer            51      M              4.0
# 7   818906208  Existing Customer            32      M              0.0
# 8   710930508  Existing Customer            37      M              3.0
# 9   719661558  Existing Customer            48      M              2.0
# 10  708790833  Existing Customer            42      M              5.0
# 11  710821833  Existing Customer            65      M              1.0
# ...

# %%
import pandas as pd
df=pd.read_csv('D:\\AI ML B2\\CreditCard9.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CLIENTNUM            19 non-null     int64
#  1   Attrition_Flag       19 non-null     object
#  2   Customer_Age         19 non-null     int64
#  3   Gender               19 non-null     object
#  4   Dependent_count      17 non-null     float64
#  5   Education_Level      18 non-null     object
#  6   Income_Category      18 non-null     object
#  7   Credit_Limit         19 non-null     int64
#  8   Total_Revolving_Bal  17 non-null     float64
#  9   Avg_Purchase         17 non-null     float64
#  10  Total_Trans_Amt      18 non-null     float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1.8+ KB

# %%
import pandas as pd
Creditcard9=pd.read_csv('D:\\AI ML B2\\CreditCard9.csv')
Creditcard9.isna()
# Out:
#     CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0       False           False         False   False            False
# 1       False           False         False   False            False
# 2       False           False         False   False            False
# 3       False           False         False   False             True
# 4       False           False         False   False            False
# 5       False           False         False   False            False
# 6       False           False         False   False            False
# 7       False           False         False   False            False
# 8       False           False         False   False            False
# 9       False           False         False   False            False
# 10      False           False         False   False            False
# 11      False           False         False   False            False
# 12      False           False         False   False            False
# ...

# %%
sr=pd.Series([2,5,None,5,None,11])
sr
# Out:
# 0     2.0
# 1     5.0
# 2     NaN
# 3     5.0
# 4     NaN
# 5    11.0
# dtype: float64

# %%
import pandas as pd
df=CreditCard9.drop(['Dependent_count'],axis = 1)
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pd
# ----> 2 df=CreditCard9.drop(['Dependent_count'],axis = 1)
#       3 df.isnull().sum()
#
# NameError: name 'CreditCard9' is not defined
